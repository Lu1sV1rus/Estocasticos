# %% [markdown]
# <a href="https://colab.research.google.com/github/Lu1sV1rus/Estocasticos/blob/main/Caminata_aleatoria_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><font size="6">Caminata Aleatoria 1D</font></p>
#
# ---
#
# <p><font size="3">
# Este código simula el movimiento de una partícula en una dimensión (línea recta).
# <br>Es la base para entender modelos financieros como el <font color="tomato"> Movimiento Browniano</b>.
# </font></p>
#
# <hr size="2" ">
#
# <p><font size="4">Variables y Probabilidades</font></p>
#
# <ul>
#     <p><font size="3">Probabilidad de éxito (moverse a la derecha, +1):<font color="tomato"> p</font></p>
#     <p><font size="3">Probabilidad de fracaso (moverse a la izquierda, -1):<font color="tomato"> q</font></p>
#     <p><font size="3">Condición:<font color="tomato"> p + q = 1</font></p>
# </ul>
#
# ---
#
# <p><font size="4" color="tomato">Librerías Utilizadas</b></font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">import random as r</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Genera los números aleatorios para decidir el paso.</font>
# </p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">import matplotlib.pyplot as plt</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Se encarga de graficar el recorrido de la caminata.</font>
# </p>

# %%
'''Codigo de una caminata aleatoria 1D, con probabilidad p de moverse a la
derecha y probabilidad q de moverse a la izquierda, tal que p + q = 1.'''
#Importamos las liberias
import random as r
import matplotlib.pyplot as plt

# %% [markdown]
# <p><font size="5">Función: Caminata(w, c)</font></p>
#
# <p><font size="3">
# Define la lógica del movimiento paso a paso y almacena el historial de la posición.
# </font></p>
#
# <hr size="2">
#
# <p><font size="4">Parámetros de Entrada</font></p>
#
# <ul>
#     <p><font size="3">Número total de pasos a realizar:<font color="tomato"> w</font></p>
#     <p><font size="3">La probabilidad de que se mueva a la derecha (o izquierda):<font color="tomato"> c</font></p>
# </ul>
#
# ---
#
# <p><font size="4">Proceso Lógico</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">x = 0  y  h = []</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Se inicializa la posición en el origen y se crea la lista del historial.</font>
# </p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">Ciclo For (w)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Por cada paso, se genera un número aleatorio entre 0 y 1.</font>
# </p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">If (p > c)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Si el número es mayor al umbral, avanza (+1); de lo contrario, retrocede (-1).</font>
# </p>
#
# ---
#
# <p><font size="4">Salida del Código</font></p>
#
# <ul>
#     <p><font size="3">Imprime la posición final:<font color="tomato"> print(x)</font></p>
#     <p><font size="3">Devuelve la lista con todos los puntos:<font color="tomato"> return h</font></p>
# </ul>

# %%
def caminata(w,c):
  x=0                                   # Posicion inicial
  h=[]                                  # Lista del historial
  h.append(x)                           # Primer punto del historial
  for i in range(w):                    # Ciclo for
    p=r.random()                        # Genero un numero aleatorio
    if p>c:                             # Si el numero es mayor al umbral
      x+=1                              # Crece en 1 unidad
      h.append(x)                       # Almaceno la nueva posicion
    else:                               # Si el numero es menor al umbral
      x-=1                              # Decrece en 1 unidad
      h.append(x)                       # Almaceno la nueva posicion
  print("La ultima posición: ",x)       # Imprimo la ultimo posicion
  return h                              # Retorno la lista de posiciones

# %% [markdown]
# <p><font size="5">Ejecución del Modelo</font></p>
#
# <p><font size="3">
# Se definen las condiciones iniciales y se llama a la función para obtener los resultados de la simulación.
# </font></p>
#
# <hr size="2">
#
# <p><font size="4">Configuración de Variables</font></p>
#
# <ul>
#     <p><font size="3">Probabilidad límite (50% para cada lado):<font color="tomato"> c = 0.5</font></p>
#     <p><font size="3">Cantidad de iteraciones en la serie:<font color="tomato"> w = 100</font></p>
# </ul>
#
# ---
#
# <p><font size="4">Llamada a la Función</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">s1 = caminata(w, c)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Se ejecuta el proceso y se almacena la lista de posiciones en la variable "s1".</font>
# </p>
#
# ---
#
# <p><font size="4">Interpretación Financiera</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">Al usar un <font color="tomato">c = 0.5</font>, es un camino aleatorio con la misma oportunidad de crecer como decrecer</font>
# </p>

# %%
# Probabilidad
c=0.5
# Pasos
w=100
# Funcion
s1=caminata(w,c)
# Out:
# La ultima posición:  8

# %% [markdown]
# <p><font size="5">Visualización: Matplotlib</font></p>
#
# <p><font size="3">
# Generación del gráfico lineal para observar el comportamiento estocástico de la partícula.
# </font></p>
#
# <hr size="2">
#
# <p><font size="4">Configuración de la grafica</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">plt.figure(figsize=(12,4))</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Define un área de dibujo extendida para apreciar mejor las fluctuaciones.</font>
# </p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">plt.axhline(y=0, color='red')</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Dibuja una línea horizontal en el origen (cero) como referencia visual.</font>
# </p>
#
# ---
#
# <p><font size="4">Etiquetado y Trazado</font></p>
#
# <ul>
#     <p><font size="3">Título del gráfico:<font color="tomato"> 'Caminata aleatoria 1D'</font></p>
#     <p><font size="3">Ejes:<font color="tomato"> Valor (Y) vs Iteraciones (X)</font></p>
# </ul>
#
#
#
# ---
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">plt.plot(s1)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Grafica la serie de datos.</font>
# </p>

# %%
# Grafica
plt.figure(figsize=(12,4))                          # Creo el plano
plt.axhline(y=0, linestyle="--", color='red')       # Agrego una linea en X
plt.title('Caminata aleatoria 1D')                  # Titulo
plt.xlabel('Iteraciones')                           # Eje X
plt.ylabel('Valor')                                 # Eje Y
plt.plot(s1, color='navy')                          # Muestro la grafica

# %% [markdown]
# <p><font size="5">Función: ceros(s1)</font></p>
#
# <p><font size="3">
# Contabiliza cuántas veces la caminata aleatoria regresa o cruza el punto de origen (cero).
# </font></p>
#
# <hr size="2">
#
# <p><font size="4">Lógica del Contador</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">g = -1</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Se inicializa en -1 para no contar la posición inicial (el cero de arranque).</font>
# </p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">for i in range(len(s1))</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Recorre toda la lista de posiciones generada en la simulación.</font>
# </p>
#
# ---
#
# <p><font size="4">Condición</font></p>
#
# <ul>
#     <p><font size="3">Si la posición actual es igual a cero:<font color="tomato"> if s1[i] == 0</font></p>
#     <p><font size="3">Aumenta el contador de encuentros:<font color="tomato"> g += 1</font></p>
# </ul>
#
# ---
#
# <p><font size="4">Resultado Final</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">print(g)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;El número total de veces que paso por el origen.</font>
# </p>

# %%
# Extra conteos de ceros
def ceros(s1):                                  # Creo una funcion
  g=-1                                          # Inicio el conteo
  for i in range(len(s1)):                      # Ciclo for
    if s1[i]==0:                                # Condicion
      g+=1                                      # Contador
  # Imprimo el resultado
  print("El número total de veces que paso por el origen: ",g)

ceros(s1)                                       # Funcion para contar ceros
# Out:
# El número total de veces que paso por el origen:  2

# %% [markdown]
# <p><font size="5">S2: Simulación con tendencia positiva</font></p>
#
# <p><font size="3">
# La probabilidad <font color="tomato"> c = 0.2</font> favorece el crecimiento.
# </font></p>
#
# <hr size="2">
#
# <p><font size="4">Configuración del Drift</font></p>
#
# <ul>
#     <p><font size="3">Nueva probabilidad límite:<font color="tomato"> c = 0.2</font></p>
#     <p><font size="3">Interpretación:<font color="tomato"> 80% derecha / 20% izquierda</font></p>
# </ul>
#
# ---
#
# <p><font size="4">Ejecución y Gráfica</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">s2 = caminata(w, 0.2)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Al ser el umbral muy bajo, la condición "p > c" se cumple la mayoría de las veces.</font>
# </p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">plt.plot(s2)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Grafica la serie de datos.</font>
# </p>

# %%
# Funcion con tendencia a la derecha (crece)
# Funcion s2
s2=caminata(w,0.2)
# Llamo a la funcion
ceros(s2)
# Grafica
plt.figure(figsize=(12,4))                          # Creo el plano
plt.axhline(y=0, linestyle="--", color='red')       # Agrego una linea en X
plt.title('Caminata tendencia a la derecha 1D')     # Titulo
plt.xlabel('Iteraciones')                           # Eje X
plt.ylabel('Valor')                                 # Eje Y
plt.plot(s2, color='green')                         # Muestro la grafica
# Out:
# La ultima posición:  62
# El número total de veces que paso por el origen:  0

# %% [markdown]
# <p><font size="5">S3: Simulación con tendencia negativa</font></p>
#
# <p><font size="3">
# La probabilidad <font color="tomato"> c = 0.8</font> favorece el decrecimiento.
# </font></p>
#
# <hr size="2">
#
# <p><font size="4">Configuración del Drift</font></p>
#
# <ul>
#     <p><font size="3">Nueva probabilidad límite:<font color="tomato"> c = 0.8</font></p>
#     <p><font size="3">Interpretación:<font color="tomato"> 20% derecha / 80% izquierda</font></p>
# </ul>
#
# ---
#
# <p><font size="4">Ejecución y Gráfica</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">s3 = caminata(w, 0.8)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Al ser el umbral alto, la condición "p > c" rara vez se cumple, provocando el descenso.</font>
# </p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">plt.plot(s3)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Grafica la serie de datos en sentido negativo.</font>
# </p>

# %%
# Funcion con tendencia a la izquierda (decrece)
# Funcion s3
s3=caminata(w,0.8)
# Llamo a la funcion
ceros(s3)
# Grafica
plt.figure(figsize=(12,4))                          # Creo el plano
plt.axhline(y=0, linestyle="--", color='red')       # Agrego una linea en X
plt.title('Caminata con tendencia a la izquierda 1D')       # Titulo
plt.xlabel('Iteraciones')                           # Eje X
plt.ylabel('Valor')                                 # Eje Y
plt.plot(s3, color='orange')                        # Muestro la grafica
# Out:
# La ultima posición:  -58
# El número total de veces que paso por el origen:  2

# %% [markdown]
# <p><font size="5">Ley de los Grandes Números</font></p>
#
# <p><font size="3">
# Simulación a gran escala para observar la convergencia de los resultados hacia su esperanza matemática.
# </font></p>
#
# <font size="2">A un millón de pasos, la serie <font color="tomato">s1</font> se mantiene relativamente cerca del cero,
# <br>&nbsp;&nbsp;&nbsp;&nbsp;mientras que <font color="tomato">s2</font> y <font color="tomato">s3</font> muestran pendientes casi perfectas hacia arriba y hacia abajo.</font>
# </p>
#
# <hr size="2">
#
# <p><font size="4">Simulación Masiva</font></p>
#
# <ul>
#     <p><font size="3">Número de iteraciones :<font color="tomato"> w = 1,000,000</font></p>
#     <p><font size="3">Objetivo:<font color="tomato"> Minimizar el ruido aleatorio para resaltar la tendencia.</font></p>
# </ul>
#
# ---
#
# <p><font size="4">Visualización y Leyendas</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">plt.plot(s1, s2, s3, label=...)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Se asigna una etiqueta descriptiva a cada serie para facilitar la lectura.</font>
# </p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">plt.legend()</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Despliega un cuadro informativo vinculando cada color con su probabilidad <font color="tomato">c</font>.</font></p>

# %%
# Ley de los grandes numeros
w=1000000                                  # Numero de iteraciones
s1=caminata(w,0.5)                         # Funcion neutral
s2=caminata(w,0.2)                         # Funcion derecha
s3=caminata(w,0.8)                         # Funcion izquierda

plt.figure(figsize=(12,4))                          # Creo el plano
plt.axhline(y=0, linestyle="--", color='red')       # Agrego una linea en X
plt.title('Caminata con tendencias 1D')             # Titulo
plt.xlabel('Iteraciones')                           # Eje X
plt.ylabel('Valor')                                 # Eje Y
# Muestro la grafica
plt.plot(s1, label='Neutral (0.5)', color='blue')
plt.plot(s2, label='Derecha (0.2)', color='green')
plt.plot(s3, label='Izquierda (0.8)', color='orange')
plt.legend()                                       # Muestro las etiquetas
# Out:
# La ultima posición:  2372
# La ultima posición:  601352
# La ultima posición:  -600482

# %% [markdown]
# <p><font size="5">Función Aleatoria Doble: rmmm(w)</font></p>
#
# <p><font size="3">
# Simulación donde la probabilidad de éxito <font color="tomato">c</font> no es fija, sino que se recalcula en cada paso.
# </font></p>
#
# <hr size="2">
#
# <p><font size="4">Doble Aleatoriedad</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">c = r.random()</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;En cada iteración, el umbral de decisión cambia aleatoriamente.</font>
# </p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">p = r.random()</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Se genera el número aleatorio para comparar contra el umbral variable.</font>
# </p>
#
# ---
#
# <p><font size="4">Proceso e Historial</font></p>
#
# <ul>
#     <p><font size="3">Comparación dinámica:<font color="tomato"> if p > c</font></p>
#     <p><font size="3">Resultado por paso:<font color="tomato"> +1 o -1</font></p>
# </ul>
#
#
#
# ---
#
# <p><font size="4">Salida de Consola</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">print("La ultima posición: ", x)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Muestra el paradero final tras la doble incertidumbre.</font>
# </p>

# %%
# Extra la probabilidad de exito tambien es aleatoria
def rmmm(w):                            # Creo una funcion
  x=0                                   # Posicion inicial
  h=[]                                  # Lista del historial
  h.append(x)                           # Primer punto del historial
  for i in range(w):                    # Ciclo for
    c=r.random()                        # Genero una probabilidad aleatoria
    p=r.random()                        # Genero un numero aleatorio
    if p>c:                             # Si el numero es mayor al umbral
      x+=1                              # Crece en 1 unidad
      h.append(x)                       # Almaceno la nueva posicion
    else:                               # Si el numero es menor al umbral
      x-=1                              # Decrece en 1 unidad
      h.append(x)                       # Almaceno la nueva posicion
  print("La ultima posición: ",x)       # Imprimo la ultimo posicion
  return h                              # Retorno la lista de posiciones

# %% [markdown]
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">m = rmmm(100)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Se ejecuta la función con 100 pasos y se guarda el historial en "m".</font>
# </p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">ceros(m)</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Calcula cuántas veces el sistema regresó al equilibrio inicial.</font>
# </p>

# %%
m=rmmm(100)                             # Funcion con doble aletoriedad
ceros(m)                                # Funcion para contar ceros
# Out:
# La ultima posición:  0
# El número total de veces que paso por el origen:  19

# %% [markdown]
# <p><font size="3">
# Gráfica de <font color="tomato">m</font> donde tanto el paso como el umbral son aleatorios.
# </font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="3" color="tomato">plt.plot(m, label='random', color='brown')</font>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">&nbsp;&nbsp;&nbsp;&nbsp;Se utiliza el color café para representar esta serie de alta incertidumbre.</font>
# </p>

# %%
# Grafica
plt.figure(figsize=(12,4))
plt.axhline(y=0, linestyle="--", color='red')
plt.title('Caminata con tendencia a la izquierda 1D')
plt.xlabel('Iteraciones')
plt.ylabel('Valor')
plt.plot(m, color='brown')

# %% [markdown]
# <p><font size="5">Conclusion</font></p>
#
# ---
#
# <p><font size="4">Modificar la probabilidad (<font color="tomato">c</font>)</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">Se demostró que con variaciones en la probabilidad <font color="tomato">c</font> se alteran totalmente los resultados finales.
#
# ---
#
# <p><font size="4">Ley de los grandes números</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">Al aumentar las iteraciones a <font color="tomato">w = 1,000,000</font>, el azar individual se diluye.
# <br>&nbsp;&nbsp;&nbsp;&nbsp;La ley de los grandes números obliga a la serie a seguir su esperanza matemática, haciendo que las tendencias sean líneas prácticamente rectas.</font>
# </p>
#
# ---
#
# <p><font size="4">Doble Aletoriedad (rmmm)</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;
# <font size="2">La función con probabilidad (<font color="tomato">c</font>) aleatoria es la más realista. Aunque tiende a la neutralidad,
# <br>&nbsp;&nbsp;&nbsp;&nbsp;su camino es mucho más aleatorio. Esta funcion contiene uno desarrollo mas caotico, ya que con cada iteracion se modifica tanto la probabilidad <font color="tomato">c</font> como la probabilidad obtenida <font color="tomato">p</font> lo que hace un camino aun mas aleatorio.</font>
# </p>
#
# ---
#
# <p><font size="4">Resultado del Conteo de Ceros</font></p>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;<font size="3" color="tomato">Serie neutral: </font> <font size="3"> Alta frecuencia de retorno al origen.</font></p>
# <p>&nbsp;&nbsp;&nbsp;&nbsp;<font size="3" color="tomato">Series con tendencia:</font><font size="3"> Escaso o nulo retorno al origen, ya que crecen/decrecen rapidamente.</font></p>
